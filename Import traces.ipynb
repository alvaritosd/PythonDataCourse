# %%
#this imports FFF recordings and the stim file generated by motyxia

# %%
from axolotl.schema import recordings, ephys, subjects
import pandas as pd
import puffbird as pb
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib widget
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-700122856313> in <module>
# ----> 1 from axolotl.schema import recordings, ephys, subjects
#       2 import pandas as pd
#       3 import puffbird as pb
#       4 import numpy as np
#       5 import seaborn as sns
#
# ModuleNotFoundError: No module named 'axolotl'

# %%
# set your restriction key

key = {
    'subject_name':'ASD190521#000',
    'recording_id':1,
    'subrecording_id':1, 
    'import_name':'axoread_alvaro3', 
    'psth_name':'ledsteps2'
}

# %%
# autopopulate and import raw intracellular table

recordings.RecIntracellularImported().autopopulate(
    key['import_name'], key, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e86831656d5d> in <module>
#       1 # autopopulate and import raw intracellular table
#       2
# ----> 3 recordings.RecIntracellularImported().autopopulate(
#       4     key['import_name'], key, verbose=True)
#
# NameError: name 'recordings' is not defined

# %%
table = recordings.RecIntracellularImported()
table.test_table(key['import_name'], key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7743c2f0f87c> in <module>
# ----> 1 table = recordings.RecIntracellularImported()
#       2 table.test_table(key['import_name'], key)
#
# NameError: name 'recordings' is not defined
